# %%
import sys

sys.path.append('/home/citsec/rtg')

# %%
import rtg

# %%
rtg.login('view', 'view', 'http://localhost:8080')

# %%
p=[]
import time
for i in range(100):
    p.append(rtg.get()[0]['zurich']['apples'].ask.price)
    time.sleep(2)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(p)
